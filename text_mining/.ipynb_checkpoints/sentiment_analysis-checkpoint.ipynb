# %% [markdown]
# # Python NLTK sentiment analysis
#
# *Sources_from : Peter Nagy's kaggle page*
#
# __Sentiment Analysis : the process of computationally identifying and categorizing opinions expressed in a piece of text, especially in order to determine whether the writer's attitude towards a particular topic, product, etc is postive, negative, or neutral.__

# %%
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split # function for splitting data to train and test sets 

import nltk
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier

from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt 
# %matplotlib inline 

from subprocess import check_output

# %%
data=pd.read_csv("Sentiment.csv")
data.head()
# Out:
#    id               candidate  candidate_confidence relevant_yn  \
# 0   1  No candidate mentioned                   1.0         yes
# 1   2            Scott Walker                   1.0         yes
# 2   3  No candidate mentioned                   1.0         yes
# 3   4  No candidate mentioned                   1.0         yes
# 4   5            Donald Trump                   1.0         yes
#
#    relevant_yn_confidence sentiment  sentiment_confidence     subject_matter  \
# 0                     1.0   Neutral                0.6578  None of the above
# 1                     1.0  Positive                0.6333  None of the above
# 2                     1.0   Neutral                0.6629  None of the above
# 3                     1.0  Positive                1.0000  None of the above
# 4                     1.0  Positive                0.7045  None of the above
#
#    subject_matter_confidence candidate_gold  ... relevant_yn_gold  \
# 0                     1.0000            NaN  ...              NaN
# 1                     1.0000            NaN  ...              NaN
# 2                     0.6629            NaN  ...              NaN
# 3                     0.7039            NaN  ...              NaN
# 4                     1.0000            NaN  ...              NaN
#
#   retweet_count  sentiment_gold subject_matter_gold  \
# 0             5             NaN                 NaN
# 1            26             NaN                 NaN
# 2            27             NaN                 NaN
# 3           138             NaN                 NaN
# 4           156             NaN                 NaN
#
#                                                 text tweet_coord  \
# 0  RT @NancyLeeGrahn: How did everyone feel about...         NaN
# 1  RT @ScottWalker: Didn't catch the full #GOPdeb...         NaN
# 2  RT @TJMShow: No mention of Tamir Rice and the ...         NaN
# 3  RT @RobGeorge: That Carly Fiorina is trending ...         NaN
# 4  RT @DanScavino: #GOPDebate w/ @realDonaldTrump...         NaN
#
#                tweet_created            tweet_id  tweet_location  \
# 0  2015-08-07 09:54:46 -0700  629697200650592256             NaN
# 1  2015-08-07 09:54:46 -0700  629697199560069120             NaN
# 2  2015-08-07 09:54:46 -0700  629697199312482304             NaN
# 3  2015-08-07 09:54:45 -0700  629697197118861312           Texas
# 4  2015-08-07 09:54:45 -0700  629697196967903232             NaN
#
#                 user_timezone
# 0                       Quito
# 1                         NaN
# 2                         NaN
# 3  Central Time (US & Canada)
# 4                     Arizona
#
# [5 rows x 21 columns]

# %% [markdown]
# we decided to only do sentiment analysis on the dataset, therefore we just selected only text and sentiment columns.

# %%
data=data[['sentiment','text']]
data.head()
# Out:
#   sentiment                                               text
# 0   Neutral  RT @NancyLeeGrahn: How did everyone feel about...
# 1  Positive  RT @ScottWalker: Didn't catch the full #GOPdeb...
# 2   Neutral  RT @TJMShow: No mention of Tamir Rice and the ...
# 3  Positive  RT @RobGeorge: That Carly Fiorina is trending ...
# 4  Positive  RT @DanScavino: #GOPDebate w/ @realDonaldTrump...

# %% [markdown]
# first of all, splitting the dataset into a training and a testing set. The test set is the 10% of the original dataset. For the particular analysis, we dropped the neutral tweets, as my goal was to only differentiate positive and negative tweets.

# %%
train,test=train_test_split(data,test_size=0.1)
train=train[train['sentiment']!="Neutral"]

# %% [markdown]
# as a next step, we separated the Positive and negative tweets of the training set in order to easily visualize their contained word. After that i cleaned the text from hashtags, mentions and links,. Now they were ready for a Wordcloud visualizaion whcih shows only the most emphatic words of the Positve and Negative tweets.

# %%
# %%time
train_pos=train[train['sentiment']=="Positive"]
train_pos=train_pos["text"]
train_neg=train[train['sentiment']=="Negative"]
train_neg=train_neg['text']

def wordcloud_draw(data,color="black"):
    words=' '.join(data)
    cleaned_word=" ".join([word for word in words.split() if "http" not in word and not word.startswith("@") and not word.startswith("#") and word!="RT"])
    wordcloud=WordCloud(stopwords=STOPWORDS,background_color=color,width=2500,height=2000).generate(cleaned_word)
    plt.figure(1,figsize=[13,13])
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()
    
print("Positive words")
wordcloud_draw(train_pos,color="white")
print("negative words")
wordcloud_draw(train_neg)
# Out:
# Positive words
# negative words
# Wall time: 48.5 s

# %% [markdown]
# interesting to notice the following words and expressions in the positive word set: truth, strong, legitimate, together, love, job
#
# In author's interpretation, people tend to believe that their ideal candidate is truthful, legitimate, together, love, job
#
# ____
#
# at the same time, negative tweets contains words like, influence, news, elevator, music, disappointing, softball, makeup, cherry picking, trying
#
# in author's interpretation, pplt missed the decisively acting and considered the scolded candidates too soft and cherry picking

# %% [markdown]
# after the visualization, lets remove the hashtags, mentions, linjks and stopwords from the training set.
#
# __Stop Word__: Stop words are words which do not contain important significance to be used in Search Queries, Usually these words are filtered out from search queries because they return vast amount of unnecessary information(the, for, htis,..)

# %%
train.head()
# Out:
#      sentiment                                               text
# 9584  Negative  RT @RWSurferGirl: Jeb Bush reminds me of eleva...
# 8991  Negative  RT @RWSurferGirl: I'd really like to see how l...
# 4556  Negative  RT @CJsucitymvp: "but i don't wanna eat my veg...
# 5433  Negative  Let's change the racist usage of the word arti...
# 2253  Negative  RT @shannonrwatts: #NRA built massive database...

# %%
print(train)
# Out:
#       sentiment                                               text
# 9584   Negative  RT @RWSurferGirl: Jeb Bush reminds me of eleva...
# 8991   Negative  RT @RWSurferGirl: I'd really like to see how l...
# 4556   Negative  RT @CJsucitymvp: "but i don't wanna eat my veg...
# 5433   Negative  Let's change the racist usage of the word arti...
# 2253   Negative  RT @shannonrwatts: #NRA built massive database...
# ...         ...                                                ...
# 9264   Negative  #GOPDebates Calling SS an entitlement is obsce...
# 10232  Negative  Paul is the devil.... #GOPDebates I'm scared i...
# 12143  Negative  #GOPDebates respect life? What about a woman's...
# 5333   Negative  Last night at the #GOPdebate all I saw was a b...
# 5987   Positive  Anybody watch the @realDonaldTrump roast last ...
#
# [9641 rows x 2 columns]

# %%
                
tweets = []
stopwords_set = set(stopwords.words("english"))

for index, row in train.iterrows():
    words_filtered = [e.lower() for e in row.text.split() if len(e) >= 3]
    words_cleaned = [word for word in words_filtered
        if 'http' not in word
        and not word.startswith('@')
        and not word.startswith('#')
        and word != 'RT']
    words_without_stopwords = [word for word in words_cleaned if not word in stopwords_set]
    tweets.append((words_without_stopwords, row.sentiment))

test_pos = test[ test['sentiment'] == 'Positive']
test_pos = test_pos['text']
test_neg = test[ test['sentiment'] == 'Negative']
test_neg = test_neg['text']

# %% [markdown]
# as a next step, lets extract the so called features with nltk lib, first by measuring frequent distribution and by selecting the resulting keys.

# %%
test_pos.head()
# Out:
# 4454    Trump slams Megyn Kelly http://t.co/oBNQDPOemX...
# 59      RT @KarrattiPaul: Join ISIS and sign your deat...
# 746     "@FoxNews: .@brithume: “The best closing state...
# 9121    RT @kwrcrow: Dr. Carson remark on DC having ha...
# 9376    RT @DonnieWahlberg: Enjoyed the #GOPDebates an...
# Name: text, dtype: object

# %%
tweets
# Out:
# [(['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (["i'd",
#    'really',
#    'like',
#    'see',
#    'long',
#    'candidate',
#    'given',
#    'speak.',
#    'seem',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'all.'],
#   'Negative'),
#  (['"but', 'wanna', 'eat', 'vegetables"'], 'Negative'),
#  (["let's",
#    'change',
#    'racist',
#    'usage',
#    'word',
#    'articulate',
#    'describe',
#    'republicans',
#    'well',
#    'spoken.'],
#   'Negative'),
#  (['built',
#    'massive',
#    'database',
#    'gun',
#    'owners',
#    'opposing',
#    'national',
#    'gun',
#    'registry'],
#   'Negative'),
#  (['candidates', 'attack', 'fox', 'stoping', 'speaking.'], 'Negative'),
#  (['koch'], 'Negative'),
#  (['ted', "cruz's", 'mutant', 'superpower', 'fear-mongering.'], 'Negative'),
#  (['huckabee:',
#    '"we',
#    'need',
#    'banish',
#    'department',
#    'education!',
#    "can't",
#    'voters',
#    'educated!!"'],
#   'Negative'),
#  (['ask',
#    'trump',
#    'legitimate',
#    'question.',
#    'look',
#    "wallace's",
#    'face',
#    'trump',
#    'nails',
#    'it.'],
#   'Positive'),
#  (['thin-skinned', 'feel', 'sorry', 'fool', 'us.'], 'Negative'),
#  (["i'll",
#    'tell',
#    'one',
#    'good',
#    'thing',
#    'candidates',
#    'tripping',
#    'outdo',
#    'sexism…'],
#   'Negative'),
#  (['best',
#    'thing',
#    'wiping',
#    'floor',
#    'jihad',
#    'enabling',
#    'policies.',
#    'well',
#    'done.'],
#   'Positive'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['nope.',
#    'think',
#    'unintentionally',
#    'funny',
#    'political',
#    'event',
#    "i've",
#    'ever',
#    'seen.',
#    'great!'],
#   'Negative'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Negative'),
#  (['actually',
#    'trump,',
#    'live',
#    'least',
#    'violent',
#    'time',
#    'human',
#    'history.'],
#   'Positive'),
#  (['person', 'worse', 'kasich', 'last', 'night', 'megyn', 'kelly…'],
#   'Negative'),
#  (['megyn',
#    'kelly:',
#    'would',
#    'defeat',
#    'isis',
#    'days?',
#    'ted',
#    'cruz:',
#    'green',
#    'lantern',
#    'ring,',
#    'course.'],
#   'Negative'),
#  (['spoiler', 'alert:', 'every', 'candidate', 'thinks', 'knows', 'wants.'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['clown', 'show.'], 'Negative'),
#  (['abortion',
#    'murder',
#    "y'all,",
#    'cops',
#    'keep',
#    'abusing',
#    'system',
#    'murdering',
#    'black',
#    'people',
#    "y'all",
#    'wanna',
#    'quiet?'],
#   'Negative'),
#  (['focus', 'group', 'laugh.', 'statistically', 'significant.'], 'Negative'),
#  (['audience', 'loves', 'carson'], 'Positive'),
#  (["what's",
#    'thoughts',
#    'comments',
#    'facebook',
#    'page',
#    'concerning',
#    'motive',
#    'behind'],
#   'Negative'),
#  (['"stay',
#    'tuned',
#    'closing',
#    'statements,',
#    'final',
#    'thoughts,',
#    'god."',
#    'turned',
#    'tv,',
#    "i'm",
#    'good.'],
#   'Negative'),
#  (['enjoyed', 'looking', 'forward', 'next.'], 'Positive'),
#  (['smart',
#    'kasich',
#    'say,',
#    'essentially,',
#    'hear',
#    'concerns',
#    'trump',
#    'voters',
#    'except',
#    "i'm",
#    'sane"'],
#   'Negative'),
#  (['see',
#    'political',
#    'commentators',
#    'saying',
#    'watch',
#    "he's",
#    'making',
#    'som…'],
#   'Positive'),
#  (['waters,',
#    'waters,',
#    'rising',
#    'fast;',
#    'history',
#    'catching',
#    'last.',
#    "that's",
#    'nutshell.',
#    'aldon',
#    'smith',
#    'king'],
#   'Negative'),
#  (['very,',
#    'put',
#    'politely,',
#    'macho?',
#    'people',
#    'argue',
#    'penis',
#    'size',
#    'generally',
#    'small',
#    'ones.'],
#   'Negative'),
#  (['walker:', 'god', 'cutting', 'budget.', 'talk', 'him.'], 'Negative'),
#  (['.@allahpundit',
#    'best',
#    'part',
#    "rush's",
#    'opening--his',
#    'reporting',
#    'backlash',
#    "they've",
#    'forgotten',
#    'audience'],
#   'Negative'),
#  (['hugged', 'obama', 'deserve', 'stage', 'tonight.'], 'Negative'),
#  (['trump', 'cam', 'hands.'], 'Negative'),
#  (['no,',
#    'scott',
#    'walker,',
#    '"lash"',
#    'protesters',
#    'wisconsin...',
#    'arrested.'],
#   'Negative'),
#  (['likes',
#    'socialized',
#    'med',
#    'paying',
#    'corrupt',
#    'politicians.',
#    'conservatives',
#    'like',
#    'him,',
#    'why?#gopdebate'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['.@thepoliticalcat',
#    'cancel',
#    'primaries.',
#    'fox',
#    'party',
#    'set',
#    '&amp;',
#    'anointed',
#    'man',
#    'jeb',
#    'bush'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (["trump's",
#    'questions',
#    'tougher',
#    'anyone',
#    "else's.",
#    'get',
#    'center',
#    'stage',
#    'gotta',
#    'able',
#    'take',
#    'heat.'],
#   'Negative'),
#  (['people', 'color', 'audience?', 'i’m', 'asking', 'friend.'], 'Negative'),
#  (['love', 'candidates', 'talking', 'kinds', 'shit'], 'Negative'),
#  (['men', 'stage', 'discussing', 'one', 'woman.'], 'Negative'),
#  (['conservative',
#    'thinks',
#    'chris',
#    'christie',
#    'last',
#    'night,',
#    'need',
#    'leave',
#    'party',
#    'immediately.'],
#   'Negative'),
#  (['country', 'make', 'top'], 'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['watching', 'television,', 'staff', 'livetweeting', 'yells', 'tv:'],
#   'Negative'),
#  (['america',
#    'horrified',
#    'santorum',
#    'taps',
#    'rage!',
#    'tried',
#    'marginalize',
#    'w/"social',
#    'ques"',
#    'saw'],
#   'Negative'),
#  (['before...last', 'night...likely', 'lost', '"#chubclub"', 'vote..'],
#   'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['rosie', "o'donnell."], 'Negative'),
#  (['ignore',
#    'pundit',
#    'blither.',
#    'biggest',
#    'winner',
#    'last',
#    "night's",
#    'full',
#    'stop.'],
#   'Negative'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['watched',
#    'honestly',
#    'say',
#    'would',
#    'vote',
#    'rock',
#    'would',
#    'vote',
#    'democrat.',
#    'so…'],
#   'Negative'),
#  (['"this',
#    'worst',
#    'miss',
#    'america',
#    'competition',
#    'ever',
#    'seen."',
#    '-@thejoemoses'],
#   'Negative'),
#  (['love', 'great', 'one!!!!!'], 'Positive'),
#  (['think',
#    'gop',
#    'candidates',
#    'secret',
#    'crush',
#    'hillary',
#    'trashing',
#    'talking',
#    'much.'],
#   'Negative'),
#  (['intention',
#    'voting',
#    'trump,',
#    'love',
#    'guy',
#    'brand',
#    'wil',
#    'give',
#    'credit',
#    'stirring',
#    'things'],
#   'Positive'),
#  (['hate', '.@realdonaldtrump?', 'never', 'forget...', 'created', 'this.'],
#   'Negative'),
#  (["y'all",
#    'spoke',
#    'god',
#    'now?',
#    'cuz',
#    'heard',
#    'busy',
#    'making',
#    'sure',
#    'women',
#    'could',
#    'still',
#    'get',
#    'healthcare.'],
#   'Negative'),
#  (['pretty',
#    'much',
#    'eliminates',
#    'need',
#    'political',
#    'satire.',
#    "man's",
#    'walking',
#    'article.'],
#   'Negative'),
#  (['total',
#    'theatre',
#    'fox',
#    'news',
#    'tonight,',
#    'basis',
#    'fact',
#    'all...',
#    'garbage.'],
#   'Negative'),
#  (['"take', 'bottle', 'white', 'pres', 'obamas', 'policies"'], 'Negative'),
#  (['.@bipartisanism', 'talked'], 'Negative'),
#  (['like', 'watching', 'bachelorette', 'without', 'rose', 'ceremony.'],
#   'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['trump',
#    'looks',
#    'like',
#    'oompa',
#    'loompa',
#    'made',
#    'something',
#    'himself...'],
#   'Negative'),
#  (['caught', 'hour', 'frankensteins', 'singing', '"puttin\'', 'ritz".'],
#   'Negative'),
#  (['spectacle',
#    'thin-skinned',
#    'petulant',
#    'misogynist',
#    'bully',
#    'took',
#    'center',
#    'stage',
#    'trumpet',
#    'man',
#    'reveals',
#    'lit…'],
#   'Negative'),
#  (['true.', 'lot', 'people', 'agree.', 'used'], 'Positive'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['earned', '"jeb"?', 'know', 'title.'], 'Negative'),
#  (['funny',
#    'think',
#    'may',
#    'tap',
#    'now.',
#    'one',
#    'dudes',
#    'foreign',
#    'policy.…'],
#   'Negative'),
#  (['"my',
#    'record',
#    'clear.',
#    'hate',
#    'women',
#    'want',
#    'affordable',
#    'birth',
#    'control',
#    'std',
#    'screenings."'],
#   'Negative'),
#  (['wants', 'hug?'], 'Negative'),
#  (['liar,', 'trump,', 'came', 'war', 'iraq', 'businesses', 'went', 'belly'],
#   'Negative'),
#  (['like',
#    'analysis',
#    'guy',
#    'made',
#    'great',
#    'impression',
#    'think',
#    'name.#kasich'],
#   'Negative'),
#  (['big',
#    'problem',
#    'facing',
#    'democrats',
#    'get',
#    'hillary',
#    'sober',
#    'long',
#    'enough',
#    'debate?'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['think', 'actually', 'read', 'huckabee.'], 'Negative'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['creating',
#    'jobs',
#    'greatest',
#    'moral',
#    'purpose',
#    'strengthen',
#    'families',
#    '&amp;',
#    'communities.'],
#   'Positive'),
#  (["'hangover'", 'today.', 'much', 'consumed...brain', 'fried.'], 'Negative'),
#  (['summer',
#    'fun',
#    "i'm",
#    'quite',
#    'sure',
#    'feel',
#    'fact',
#    'august.',
#    'politics',
#    'makes',
#    'worse😠😍'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['almost', 'bitches', '&amp;', 'hoes.'], 'Negative'),
#  (['called',
#    'ppl',
#    'families',
#    'kia',
#    'iraq',
#    'said',
#    'sister',
#    'brother',
#    'even',
#    'call'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['trump:',
#    'would’',
#    'shut',
#    'gov’t',
#    'defund',
#    'planned',
#    'parenthood',
#    'obamacare',
#    'woot!'],
#   'Positive'),
#  (['carson:',
#    'hillary',
#    'feeds',
#    'uniformed,',
#    'depending',
#    'votes',
#    'useful',
#    'idiots...',
#    'ouch.'],
#   'Negative'),
#  (['breaking', 'arm', 'patting', 'back', 'today.', 'embarrassed'], 'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Negative'),
#  (['lots', 'dangerous', 'hot-air', 'ideologue'], 'Negative'),
#  (['tried',
#    'watch',
#    'debate,',
#    'instead',
#    'watched',
#    'millionaires',
#    'play',
#    'grew',
#    'poorest?"'],
#   'Negative'),
#  (['lessons',
#    'learnt.',
#    'women',
#    'must',
#    'babies.',
#    'education',
#    'dumb.',
#    'war',
#    'good.',
#    'obama',
#    'stupid.',
#    'fuck',
#    'immigrants.',
#    'trump',
#    'smartz.',
#    'healthcare'],
#   'Negative'),
#  (['remember', 'attack', 'tonight'], 'Negative'),
#  (['honestly', 'sure', "i'm", 'watching', 'mean', 'girls', 'even', 'here??'],
#   'Negative'),
#  (['like',
#    'come',
#    'separation',
#    'church',
#    'state',
#    'guys',
#    'killing',
#    'me.',
#    'screw',
#    'fox',
#    'news.'],
#   'Negative'),
#  (["i'd", 'say', 'carson,', 'cruz,', 'trump.'], 'Positive'),
#  (['guys',
#    'say',
#    'want',
#    'run',
#    'government,',
#    'say',
#    'want',
#    'get',
#    'government'],
#   'Negative'),
#  (['grown',
#    'ass',
#    'adult',
#    'women',
#    'right',
#    'seem',
#    'enjoy',
#    'treated',
#    'like',
#    'incompetent',
#    'children.'],
#   'Negative'),
#  (['keeping', 'spray', 'tan', 'industry', 'alive', 'thriving!'], 'Positive'),
#  (['point', 'decide', 'elect', 'prophet'], 'Negative'),
#  (['donald', 'independent!', 'rubionever', 'shows', 'work!'], 'Positive'),
#  (['glenn',
#    'beck',
#    'saying',
#    'rand',
#    'big',
#    'winner',
#    'christie',
#    'big',
#    'loser.'],
#   'Positive'),
#  (['really,', 'marco', 'rubio', 'last', "night's", 'debate', 'watching?'],
#   'Negative'),
#  (['whaa?', 'prostitues', 'pay', 'taxes??'], 'Negative'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['glad',
#    'covered',
#    '&amp;',
#    'last',
#    'night',
#    'wait,',
#    "didn't?",
#    'surprise.'],
#   'Negative'),
#  (['mood'], 'Negative'),
#  (['gop', 'respects', 'life....just', 'black', 'ones.'], 'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['personal', 'view', 'guy!'], 'Negative'),
#  (['moment', 'realize', 'watching', 'fox', 'news', 'handcuffs.'], 'Negative'),
#  (['think',
#    'gop',
#    'voters',
#    'would',
#    'demand',
#    'asinine',
#    '"i\'m',
#    "man's",
#    'man.',
#    'grab',
#    'cock,',
#    'screw',
#    'wife',
#    '&amp;',
#    'love',
#    'jesus"…'],
#   'Negative'),
#  (['"@thepatriot143:', 'hilarious!'], 'Negative'),
#  (['wins', 'snapchat'], 'Negative'),
#  (['required', 'mention', 'god', 'first', 'closing?'], 'Negative'),
#  (['jeb',
#    'bush',
#    'somewhat',
#    'impressive',
#    'unlike',
#    'trump',
#    'surprised',
#    'me.#gopdebate'],
#   'Positive'),
#  (['"please', 'ask', 'jews"', '-marco', "rubio's", 'inner', 'voice'],
#   'Negative'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['want', 'government', 'bless', 'veterans!'], 'Positive'),
#  (['lame', 'question', 'trump...', 'megan', 'kelly'], 'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['rand',
#    'paul',
#    'leading',
#    'fight',
#    'defund',
#    'planned',
#    'parenthood',
#    'read',
#    'here:'],
#   'Positive'),
#  (['wonder', 'cnn', 'address', 'issue', 'next'], 'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['rejection',
#    'medicaid',
#    'money',
#    'costing',
#    'wisconsin',
#    'nearly',
#    '$400',
#    'million'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['watch', 'tonight,', 'going', 'ask', 'won.', 'figured,', 'did.'],
#   'Negative'),
#  (['exclusive:', 'trump', 'reveals', 'renderings', 'border', 'wall'],
#   'Negative'),
#  (['btw',
#    'correct',
#    'response',
#    'last',
#    "night's",
#    "would've",
#    'been:',
#    '"my',
#    'faith',
#    'personal',
#    'matter',
#    '&amp;',
#    'unrelated',
#    'aptitude'],
#   'Negative'),
#  (['moderators',
#    'prep',
#    '4whats',
#    'coming?',
#    'abc',
#    'nbc',
#    'cnbc',
#    'cnn',
#    'willb',
#    'nasty,'],
#   'Negative'),
#  (['donald', 'trump...'], 'Negative'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Positive'),
#  (['jim',
#    'gilmore',
#    'clueless',
#    'state?',
#    'already',
#    'rule',
#    'area',
#    'larger',
#    'united',
#    'kingdom.'],
#   'Negative'),
#  (["can't",
#    'take',
#    'questions',
#    'based',
#    'history',
#    'w/o',
#    'going',
#    'off,',
#    'inability',
#    'take',
#    'heat=problem.'],
#   'Negative'),
#  (['solid', 'proof', 'rest', 'world', 'americans', 'crazy!!!'], 'Negative'),
#  (['"when',
#    'rich',
#    'wage',
#    'war',
#    'poor',
#    'die."',
#    'jean-paul',
#    'sartre',
#    'gop',
#    'foreign',
#    'policy.'],
#   'Negative'),
#  (['clear',
#    'conservatives',
#    'yet,',
#    'going',
#    'win',
#    'primary',
#    'fair',
#    'treatment',
#    'media.'],
#   'Negative'),
#  (['bushs...', 'fuck', 'jeb'], 'Negative'),
#  (['wonder', 'candidates', 'actually', 'idea', '"obama', 'idiot"'],
#   'Negative'),
#  (['way',
#    'handled',
#    'debates',
#    'last',
#    'night,',
#    'would',
#    'fair',
#    'w/airtime',
#    '&amp;',
#    'appropriate'],
#   'Negative'),
#  (['rand', 'paul', 'comes', 'across', 'bad', 'guy', 'john', 'hughes', 'film.'],
#   'Negative'),
#  (['trump',
#    'integrity-',
#    'trojan',
#    'pony',
#    'show',
#    'easily',
#    'bought',
#    '&amp;',
#    'paid',
#    'hillary'],
#   'Negative'),
#  (['watched', 'got', 'good', 'laugh.'], 'Negative'),
#  (['time',
#    'attacks,',
#    'guess,',
#    'real',
#    'conversation',
#    'issues',
#    '"i\'m',
#    'better',
#    'so-&amp;-so"'],
#   'Negative'),
#  (['aggressively', 'normal?', 'found', 'name', 'new', 'mixtape!!'],
#   'Positive'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['"how', 'earn', 'jeb?', 'jeb', 'going', 'earn', 'nomination?"'],
#   'Negative'),
#  (['“and', 'people', 'rose', 'up!”'], 'Negative'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Positive'),
#  (['require',
#    'debaters',
#    'keg',
#    'stand',
#    'prior',
#    'speaking',
#    'answering',
#    'questions'],
#   'Negative'),
#  (['ted',
#    "cruz's",
#    'slogan',
#    '"if',
#    'hate',
#    'obama,',
#    'vote',
#    'me"?',
#    'boy',
#    'pushing'],
#   'Negative'),
#  (['.@brithume:', 'think', 'clear', 'winner', '...', 'carly', 'fiorina"'],
#   'Positive'),
#  (['early2000s:',
#    'political',
#    'theater',
#    'w/"billionaires',
#    'bush',
#    '(or',
#    'gore)"',
#    'corruption',
#    'politics.',
#    'trump:',
#    'buy',
#    "'em",
#    'all!"'],
#   'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['someone', 'sense', 'humor,', 'scheduling', 'hiroshima', 'day.'],
#   'Negative'),
#  (['"[obama\'s]', 'leading', 'behind', 'disaster."', '-@sentedcruz'],
#   'Positive'),
#  (['enjoyed', 'looking', 'forward', 'next.'], 'Positive'),
#  (['activists', 'tweeted', 'highlight', 'racistpolitical', 'rhetoric', 'via'],
#   'Negative'),
#  (['dear',
#    'fox',
#    'news,',
#    'closing',
#    'argument,',
#    'none',
#    'gop',
#    'candidates',
#    'said',
#    'anything',
#    'help',
#    'suffering',
#    'women',
#    'or…'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['hopefully', "we'll", 'find', 'god', 'stands', 'taxing-pimps', 'issue.'],
#   'Negative'),
#  (['guys,',
#    'separation',
#    'church',
#    'state',
#    'also',
#    'constitution.#gopdebates'],
#   'Negative'),
#  (['winners:',
#    'megyn',
#    'kelly,',
#    'carly',
#    'fiorina,',
#    '(hopefully)',
#    "hillary's",
#    "bernie's",
#    'finance',
#    'teams.'],
#   'Negative'),
#  (['carly',
#    'fiorina',
#    'called',
#    'hillary',
#    'liar',
#    'minutes',
#    'later,',
#    'says',
#    'never'],
#   'Negative'),
#  (['must',
#    'admire',
#    'asking',
#    'tough',
#    'questions',
#    'candidates',
#    'standing',
#    'fellow',
#    'women.',
#    'proud',
#    'her.'],
#   'Positive'),
#  (['donald',
#    'trumps',
#    'loyalty',
#    'america',
#    'american',
#    'people.',
#    'political',
#    'party.'],
#   'Positive'),
#  (['official', 'photo', 'big', 'last', 'night:'], 'Negative'),
#  (['enjoyed', 'looking', 'forward', 'next.'], 'Positive'),
#  (['donald', 'trump', 'hates', 'mexicans?'], 'Negative'),
#  (['bush', 'says', 'obama', 'fix', 'brothers', 'mess', 'well', 'enough.'],
#   'Negative'),
#  (['donald', 'trumps', 'hair', 'looks', 'like', 'cotton', 'candy'],
#   'Negative'),
#  (['donald', 'trump', 'biff', 'back', 'future'], 'Negative'),
#  (['hear',
#    'gov',
#    'kasich',
#    '(ohio)',
#    'supports',
#    'fracking',
#    'including',
#    'past',
#    'attempts',
#    'frack',
#    'public',
#    'parks.'],
#   'Negative'),
#  (['donald',
#    'trump:',
#    'never',
#    'gone',
#    'bankrupt...',
#    'really',
#    'donald?',
#    'really',
#    'donald?',
#    'fucking',
#    'liar...'],
#   'Negative'),
#  (['seen',
#    'many',
#    'opinionated',
#    'white',
#    'men',
#    'room',
#    'since,',
#    'well,',
#    'guess',
#    'since',
#    'morning.',
#    'common.'],
#   'Negative'),
#  (['trump', 'supporters', 'attack', 'conservative', 'followers'], 'Negative'),
#  (['status',
#    'single',
#    'broke',
#    'last',
#    'night!',
#    'goodbye',
#    '&amp;',
#    'chris',
#    'wallace.'],
#   'Negative'),
#  (['guys,',
#    'separation',
#    'church',
#    'state',
#    'also',
#    'constitution.#gopdebates'],
#   'Negative'),
#  (['president,', 'always', 'tell', 'truth,', 'said', 'would', 'do.'],
#   'Positive'),
#  (['listening', 'like'], 'Negative'),
#  (['recap', 'want', 'make', 'choices', 'women.'], 'Negative'),
#  (['cartoons'], 'Negative'),
#  (['last', 'night?', 'think', 'commanded', 'stage.', 'harm', 'good'],
#   'Positive'),
#  (['advertising',
#    'everywhere',
#    'sells',
#    'sex',
#    'day',
#    'long,',
#    'trump',
#    "can't",
#    'say',
#    'women',
#    'would',
#    '"look',
#    'good',
#    'knees."'],
#   'Negative'),
#  (['show!', 'watching', 'republican', 'presidential', 'candidates', 'debate'],
#   'Positive'),
#  (['stop',
#    'whining',
#    'trumps',
#    'comment',
#    'you...',
#    'obviously',
#    'set',
#    'attack',
#    '&amp;',
#    'got',
#    'little',
#    'back.',
#    'deal',
#    'it!'],
#   'Negative'),
#  (['think', 'carson', 'said', 'rivals', 'nomination', 'want', 'divide', 'us.'],
#   'Negative'),
#  (['...whether', 'support', 'not.', 'shameful.'], 'Negative'),
#  (['yell', 'louder', 'man', 'better', 'man'], 'Negative'),
#  (['huckabee.'], 'Negative'),
#  (['bad', 'tipsy', 'female', "who's", 'blonde', 'roots!', '😂😂😂'], 'Negative'),
#  (['reps.',
#    'angry',
#    'iran',
#    'deal,',
#    'fair',
#    'enough,',
#    'please',
#    'offer',
#    'solution',
#    'instead',
#    'whining',
#    'attempt',
#    'peace/talks'],
#   'Negative'),
#  (['cheap',
#    'tactic',
#    'rand',
#    'paul',
#    'getting',
#    'haircut',
#    'poodle',
#    'distract',
#    'me.'],
#   'Negative'),
#  (['best', 'line', 'night'], 'Negative'),
#  (['used',
#    'biased',
#    'personal',
#    'attacks',
#    'wanted',
#    'hear',
#    'legitimate',
#    'questions.',
#    'shameful.'],
#   'Negative'),
#  (['conservatives',
#    'drag',
#    'knocked',
#    'daughters',
#    'abortion',
#    '&amp;go',
#    'right',
#    'back',
#    'protesting',
#    'next'],
#   'Negative'),
#  (['think', 'arthur', 'anderson', 'could', 'run', 'honest'], 'Negative'),
#  (['"stay',
#    'tuned',
#    'closing',
#    'statements,',
#    'final',
#    'thoughts,',
#    'god."',
#    'turned',
#    'tv,',
#    "i'm",
#    'good.'],
#   'Negative'),
#  (["they're",
#    'going',
#    'need',
#    'borrow',
#    'train',
#    'horn',
#    'next',
#    'little',
#    'bell',
#    'wimpy!'],
#   'Negative'),
#  (['excited', 'see', 'personal', 'favorites', 'continue', 'last', 'night!'],
#   'Positive'),
#  (['family', 'like', 'john', 'kasich', 'think', 'good'], 'Negative'),
#  (['believing',
#    '"god"',
#    'prerequisite',
#    'office',
#    'presidency.',
#    'talking',
#    'it?'],
#   'Negative'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['overall',
#    'view',
#    'stayed',
#    'home',
#    'work',
#    'this?"',
#    'candidate',
#    'choice',
#    'changed',
#    'iota.'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['watched', 'last', 'night,', 'send', 'morning?'], 'Positive'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['racist,', 'religious', 'fanatic', 'debate.'], 'Negative'),
#  (["we're",
#    'going',
#    'talk',
#    "trump's",
#    'bankruptcies',
#    "fiorina's",
#    'tenure',
#    'hp?',
#    'adorbs.'],
#   'Negative'),
#  (['"why',
#    "can't",
#    'everybody',
#    'else',
#    'skilled',
#    'manipulating',
#    'loopholes',
#    'screw',
#    'investors',
#    'me?',
#    'fault!"'],
#   'Negative'),
#  (['bad', 'attacked', 'moderator', 'even', 'respond', 'question.'],
#   'Negative'),
#  (['ask',
#    'trump',
#    'legitimate',
#    'question.',
#    'look',
#    "wallace's",
#    'face',
#    'trump',
#    'nails',
#    'it.'],
#   'Positive'),
#  (['chewbacca',
#    'roaring',
#    'every',
#    'while.',
#    'would',
#    'fit',
#    'right',
#    'in.',
#    'via'],
#   'Negative'),
#  (['jeb',
#    'bush:',
#    '"obama',
#    'fault,',
#    'brother,',
#    'obama',
#    'clean',
#    'mess',
#    'brother',
#    'made."'],
#   'Negative'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (["can't", 'watch', 'anymore'], 'Negative'),
#  (['lol',
#    'probably',
#    'likes',
#    'loser',
#    'candidates',
#    'like',
#    'mccain,',
#    'romney',
#    '&amp;',
#    'bush!',
#    'hands',
#    'down!',
#    'next',
#    'president',
#    'trump!'],
#   'Positive'),
#  (['parents', 'illegal', 'marco!', 'call', 'marco?'], 'Negative'),
#  (['finally', 'opportunity', 'watch', 'honestly', 'speechless...'],
#   'Negative'),
#  (['next', 'needs', 'let', 'something', 'hair!!!!!'], 'Negative'),
#  (['god.'], 'Negative'),
#  (['think', 'winner!'], 'Positive'),
#  (['republican',
#    'party',
#    'wakes',
#    'huge',
#    'hangover,',
#    'splitting',
#    'headache',
#    'idea',
#    'bed',
#    'donald',
#    'trump.'],
#   'Negative'),
#  (['unfathomable', 'would', 'ask', 'wasserman-schultz', 'postmortem'],
#   'Negative'),
#  (['need', 'take', 'control', 'debate,', 'it,'], 'Positive'),
#  (['screwed',
#    'atlantic',
#    'city',
#    'ways',
#    'kama',
#    'sutra',
#    'trump',
#    'taj',
#    'mahal.'],
#   'Negative'),
#  (['yup.', 'gone!'], 'Negative'),
#  (['scary', 'touch', 'real', 'world', 'republicans', 'are.'], 'Negative'),
#  (['career',
#    'politicians',
#    'work',
#    'washington,',
#    'guys',
#    'sure',
#    'talk',
#    'lotta',
#    'shit',
#    'career',
#    'politicians',
#    'work',
#    'washington.'],
#   'Negative'),
#  (['hey',
#    'jeb',
#    'push',
#    'keystone?',
#    'gonna',
#    'popular',
#    'fracking',
#    'states.'],
#   'Negative'),
#  (['congrats', 'harder', 'watch', 'rape', 'scene', 'irreversible.'],
#   'Negative'),
#  (['politicians',
#    'former',
#    'government',
#    'employees',
#    'really',
#    'hate',
#    'politicians',
#    'government.'],
#   'Negative'),
#  (['please',
#    'note,',
#    'lie.',
#    'world',
#    '53.3',
#    'years',
#    'oil',
#    'reserves',
#    'left.',
#    'hello,',
#    'anyone',
#    'listening?'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['last', 'night', 'jumped', 'top', 'list!'], 'Positive'),
#  (['bragged',
#    'defunding',
#    'tell',
#    'many',
#    'abortions',
#    'action',
#    'responsible',
#    'for.'],
#   'Negative'),
#  (['"the',
#    "military's",
#    'favorite',
#    'song',
#    'break',
#    'stuff',
#    'limp',
#    'bizkit"-'],
#   'Negative'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (["i'd",
#    'like',
#    'see',
#    'bunch',
#    'losers',
#    'work',
#    'construction',
#    "they're",
#    'years',
#    'old.'],
#   'Negative'),
#  (['need',
#    'order',
#    'another',
#    'green',
#    'apple',
#    'martini',
#    'process',
#    'hell',
#    'happened.'],
#   'Negative'),
#  (['again,',
#    'trump',
#    'substantiated',
#    'answer.',
#    '"people',
#    'things',
#    'give',
#    'money',
#    'stuff"'],
#   'Negative'),
#  (['laugh',
#    "'analysis'",
#    'entertainment,',
#    "that's",
#    'all.',
#    'moderators',
#    '&amp;',
#    'candidates.'],
#   'Negative'),
#  (['glad',
#    'see',
#    'jesus',
#    'got',
#    'shout-out',
#    'las',
#    "night's",
#    'debate.',
#    'candidates',
#    'pushing',
#    'envelope.'],
#   'Positive'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['loved',
#    'said',
#    "he's",
#    'made',
#    'billion',
#    'dollars.',
#    'america',
#    'owes',
#    'trillion.'],
#   'Positive'),
#  (['takeaways:',
#    'rubio',
#    'cemented',
#    'damn',
#    'good',
#    'candidate',
#    'christie',
#    'reminded',
#    'everyone',
#    "he's",
#    'legit',
#    'kasich',
#    'stood',
#    'time',
#    'given'],
#   'Positive'),
#  (['trump',
#    'admit',
#    'buying',
#    'influence',
#    'time',
#    'declaring',
#    'need',
#    'campaign',
#    'finance',
#    'reform???'],
#   'Negative'),
#  (['guess', 'laughing', 'now.'], 'Negative'),
#  (['women',
#    'shame',
#    'women',
#    'abortions',
#    'deserve',
#    'shamed',
#    'soul',
#    'self',
#    'respect.'],
#   'Negative'),
#  (['ppl',
#    'complaining',
#    'issues',
#    'covered',
#    'relax,',
#    '1st',
#    'debate!',
#    'unlike',
#    'dems,',
#    'many',
#    'come'],
#   'Positive'),
#  (['hate',
#    'political',
#    'correctness',
#    'right,',
#    'except',
#    'someone',
#    'politically',
#    'incorrect.',
#    "let's",
#    'grab',
#    'pitch',
#    'forks.'],
#   'Negative'),
#  (['“this',
#    'country',
#    'owes',
#    'trillion',
#    'dollars',
#    'need',
#    'someone',
#    'like',
#    'fix',
#    'mess”',
#    'donald',
#    'trump'],
#   'Positive'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Negative'),
#  (['last',
#    'night',
#    'phenomenal,',
#    'ratings',
#    'prove',
#    'that.',
#    'watching',
#    'biased',
#    '"news"',
#    'sources',
#    'spin',
#    'sound',
#    'bites',
#    'ridiculous.'],
#   'Negative'),
#  (["'the",
#    'government',
#    'tries',
#    'invade',
#    "church'",
#    "there's",
#    'issue',
#    'religion',
#    'invades',
#    'politics?'],
#   'Negative'),
#  (['jeb', '"there', 'establishment"', 'bush', 'retirement!'], 'Negative'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['separation', 'church', 'state,', 'never', 'knew', 'ye.'], 'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['women',
#    'shame',
#    'women',
#    'abortions',
#    'deserve',
#    'shamed',
#    'soul',
#    'self',
#    'respect.'],
#   'Negative'),
#  (['busy',
#    'enjoying',
#    'life',
#    'catch',
#    'one',
#    'draft-dodging',
#    'pricks',
#    'called',
#    'best',
#    'patriot?'],
#   'Negative'),
#  (['mom',
#    'texted',
#    'black',
#    'lives',
#    'matter',
#    'neither',
#    'black',
#    'republican',
#    'lives'],
#   'Negative'),
#  (['scott', 'walker', 'say', 'wife,', 'two', 'kids', 'harlot?'], 'Negative'),
#  (['translation,',
#    'jeb',
#    'bush,',
#    'fucked',
#    'florida',
#    'schools',
#    'badly',
#    'still',
#    'recovered.',
#    'truth,',
#    'live',
#    'here…'],
#   'Negative'),
#  (['cruz',
#    'pretty',
#    'much',
#    'saying',
#    'plan',
#    'repealing',
#    'obamacare,',
#    'shit',
#    'healthcare',
#    'afterwards"'],
#   'Negative'),
#  (['moderated',
#    'perot',
#    'debate:',
#    '"mr',
#    'perot,',
#    'ugly!',
#    'disqualify',
#    'president?"',
#    'sucked'],
#   'Negative'),
#  (['trump', 'cam', 'hands.'], 'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['chris',
#    '"9/11"',
#    'christie',
#    '9/11',
#    'mentions',
#    '9/11',
#    'every',
#    '9/11',
#    '9/11',
#    'minute',
#    'political',
#    '9/11',
#    'reasons.'],
#   'Negative'),
#  (['cruz', 'class', '&amp;', 'truth,', 'gets', 'vote!'], 'Positive'),
#  (['closing', 'statement.'], 'Negative'),
#  (['trump',
#    'said',
#    'political',
#    'system',
#    'broken',
#    'buy',
#    'politicians,',
#    'explained',
#    'exactly',
#    'many',
#    "he's…"],
#   'Negative'),
#  (["who's",
#    'real',
#    'illegal',
#    'alien',
#    'farrakhan',
#    'immigration',
#    '&amp;',
#    'mexican',
#    'bor...',
#    'via'],
#   'Negative'),
#  (['msnbc:',
#    'chris',
#    'christie',
#    'rand',
#    'paul',
#    'feud',
#    'tense',
#    'national',
#    'security',
#    'face-off'],
#   'Negative'),
#  (['congrats', 'calling', 'is!'], 'Negative'),
#  (['"benghazi"', '"ooooooooooh"', 'crowd'], 'Negative'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['discussed',
#    'seconds',
#    'later...',
#    'commercial',
#    'back',
#    'borders',
#    'abortion.'],
#   'Negative'),
#  (['busy',
#    'convincing',
#    'american',
#    'nightmare,',
#    'forgotten',
#    'engage',
#    'american',
#    'dream.'],
#   'Negative'),
#  (['immigration', 'without', 'assimilation', 'immigration,', 'invasion.'],
#   'Negative'),
#  (['know', 'tonight,', "i'm", 'certain', 'america', 'lost.'], 'Negative'),
#  (['feel', 'like', "trump's", 'hair', 'enough', 'tell', 'handle', 'things'],
#   'Negative'),
#  (['ask',
#    'trump',
#    'legitimate',
#    'question.',
#    'look',
#    "wallace's",
#    'face',
#    'trump',
#    'nails',
#    'it.'],
#   'Positive'),
#  (['carson,',
#    'carson,',
#    'carson:',
#    'dammit',
#    'man!',
#    'say',
#    'words',
#    'racism',
#    'white',
#    'supremacy',
#    'audience!'],
#   'Negative'),
#  (['love', 'candidates', 'talking', 'kinds', 'shit'], 'Negative'),
#  (['watching', 'jerry', 'springer', 'show', 'suddenly', 'realized'],
#   'Negative'),
#  (['saw',
#    'tears',
#    'jon',
#    "stewart's",
#    'last',
#    'night',
#    'daily',
#    'show,',
#    'pretend',
#    'laughed',
#    'hard',
#    'cried',
#    'watching'],
#   'Negative'),
#  (['candidates', 'attack', 'fox', 'stoping', 'speaking.'], 'Negative'),
#  (['whoah!', 'b-52s', 'fan???', 'dammit', 'might', 'like'], 'Positive'),
#  (['kasich', 'aware', "he's", 'making', 'sense?'], 'Positive'),
#  (['scott',
#    'walker',
#    'staff',
#    'sent',
#    'racist',
#    'email',
#    'ferguson',
#    'officials',
#    'ht…'],
#   'Negative'),
#  (['huckabee.'], 'Negative'),
#  (['guess',
#    "they'll",
#    'say',
#    'winner',
#    'trump,',
#    'know',
#    'trump',
#    'like',
#    'card',
#    'games',
#    'something',
#    'trumps',
#    'another.'],
#   'Negative'),
#  (['nice',
#    'see',
#    'candidates',
#    'oppose',
#    "russia's",
#    'aggressive',
#    'actions',
#    'europe.'],
#   'Positive'),
#  (['personal', 'front', 'runners'], 'Positive'),
#  (['caught',
#    'last',
#    'night…and',
#    'lost',
#    'appetite',
#    'watching',
#    'debacle!',
#    'good',
#    'figure!'],
#   'Negative'),
#  (['party:', 'sixth', 'graders', 'twitter', 'account.'], 'Negative'),
#  (['life', 'begins', 'debate', 'ends.'], 'Negative'),
#  (['creepy', 'blond', 'commentator', 'promised', 'coming', 'break.'],
#   'Negative'),
#  (['trump:',
#    'country',
#    'owns',
#    '$19',
#    'trillion',
#    'dollars',
#    'need',
#    'someone',
#    'like',
#    'fix'],
#   'Positive'),
#  (['re:',
#    'problem!ucan',
#    'continue',
#    '2ignore',
#    'facts',
#    'evidence',
#    "he's",
#    'sneaky',
#    'scumbag'],
#   'Negative'),
#  (['ask',
#    'trump',
#    'legitimate',
#    'question.',
#    'look',
#    "wallace's",
#    'face',
#    'trump',
#    'nails',
#    'it.'],
#   'Negative'),
#  (['candidates',
#    'eating',
#    'other.',
#    'tea',
#    'baggers',
#    'hate',
#    'fox',
#    'host.',
#    'donald',
#    'scores',
#    'twice',
#    'hillary.',
#    'lmao'],
#   'Negative'),
#  (['reading',
#    'blogs',
#    '&amp;',
#    'comments',
#    'regarding',
#    'last',
#    "night's",
#    'folks',
#    'saying',
#    'biggest',
#    'looser',
#    'night'],
#   'Negative'),
#  (['looking',
#    'liveblog',
#    "i'm",
#    'proud',
#    'livetweeting.',
#    'play',
#    'play',
#    'par',
#    'with...'],
#   'Positive'),
#  (["i'd",
#    'like',
#    'see',
#    'bunch',
#    'losers',
#    'work',
#    'construction',
#    "they're",
#    'years',
#    'old.'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['minutes', 'candidates', 'spoken', 'rights', 'fetuses', 'rights', 'women'],
#   'Negative'),
#  (['chance',
#    'secure',
#    'social',
#    'security',
#    'surplus',
#    '2000,',
#    'media',
#    'decided',
#    'wanted',
#    'hang',
#    'w/w',
#    'instead',
#    'fact',
#    'ch…'],
#   'Negative'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['beginning', 'end', 'going', 'anywhere', 'begin', 'with.'], 'Negative'),
#  (['come', 'fox', 'wants', 'third', 'party???'], 'Negative'),
#  (['think',
#    'dad,',
#    'career',
#    'naval',
#    'officer',
#    '(&amp;',
#    'progressive)',
#    'would',
#    'disagree',
#    'mil.',
#    'exists',
#    '"break',
#    "things'"],
#   'Negative'),
#  (['shit', 'son', 'got', 'told', 'stfu', 'hahahahaha'], 'Negative'),
#  (['hopefully', "we'll", 'find', 'god', 'stands', 'taxing-pimps', 'issue.'],
#   'Negative'),
#  (['asked',
#    'bankruptcies.',
#    'maybe',
#    'file',
#    'court',
#    'u.s.',
#    '&amp;',
#    'country',
#    'walk',
#    'away',
#    'debt'],
#   'Negative'),
#  (['kasich',
#    'knows',
#    'nothing',
#    'working',
#    'class',
#    'tired',
#    'f-ing',
#    'mailman',
#    'gig'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['comes',
#    'chase',
#    'facebook,',
#    'asking',
#    'important',
#    'questions',
#    '*hurts',
#    'forearm',
#    'making',
#    'jerk',
#    'gesture*'],
#   'Negative'),
#  (['hate',
#    'call',
#    'social',
#    'security',
#    'entitlement.',
#    'government',
#    'fund',
#    'social',
#    'security',
#    'employer',
#    'do.'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['megyn',
#    'kelly',
#    'comedy',
#    'show?',
#    'nov',
#    '2016?',
#    'considered',
#    'journalist?',
#    'no,no,'],
#   'Negative'),
#  (['would', 'never', 'know', 'frontrunner', 'watching', 'debate.'],
#   'Positive'),
#  (['"the',
#    'purpose',
#    'military',
#    'kill',
#    'people',
#    'break',
#    'things",',
#    'thought',
#    'military',
#    'national',
#    'security…'],
#   'Negative'),
#  (['focus', 'group', 'laugh.', 'statistically', 'significant.'], 'Negative'),
#  (['someone', 'send'], 'Negative'),
#  (['check', 'xm103', 'sirius206', 'wed', '9pm', 'est', 'like', 'ha…'],
#   'Negative'),
#  (["here's", 'lineup', 'anyone', 'wondering...'], 'Negative'),
#  (['pro', 'life', 'unless', 'cop', 'involved', 'gop', 'candidates'],
#   'Negative'),
#  (['trump',
#    'got',
#    'right,',
#    'nobody',
#    'would',
#    'talk',
#    'immigration,',
#    'untill',
#    'brought',
#    'up.'],
#   'Positive'),
#  (['definitely',
#    'noticed.',
#    'definitely',
#    'appreciated.',
#    'definitely',
#    'acceptable.'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['.@realdonaldtrump',
#    '"we',
#    'need',
#    'keep',
#    'illegals',
#    'out".',
#    'keep',
#    'donald',
#    'trump',
#    'out.'],
#   'Negative'),
#  (['obvious',
#    'fox',
#    'interested',
#    'controversy',
#    'sadly,',
#    'questions',
#    'designed',
#    'shock',
#    'value'],
#   'Negative'),
#  (['jim',
#    'gilmore',
#    'clueless',
#    'state?',
#    'already',
#    'rule',
#    'area',
#    'larger',
#    'united',
#    'kingdom.'],
#   'Negative'),
#  (['candidates', 'attack', 'fox', 'stoping', 'speaking.'], 'Negative'),
#  (['leader',
#    'integrity',
#    'country',
#    'beg',
#    'god',
#    'for.',
#    'get',
#    'one',
#    'upright?!!!'],
#   'Negative'),
#  (['trump',
#    '"gotcha',
#    'questions"',
#    'enlightening,',
#    'anger',
#    'provoking;',
#    'disappointing',
#    '&amp;',
#    'much',
#    'better'],
#   'Negative'),
#  (['favorite', 'part', 'candidates', 'pretend', 'people'], 'Negative'),
#  (['donald', 'trump', 'gave', 'master', 'class', 'get', 'away', 'via'],
#   'Negative'),
#  (['donald', 'trump', 'gets', 'award', 'entertaining.'], 'Positive'),
#  (['ben',
#    'carson',
#    'talk',
#    'trash.',
#    'mature',
#    'speaker',
#    'truth.',
#    'maturity',
#    'strength',
#    'display'],
#   'Positive'),
#  (['first',
#    'candidate',
#    'spend',
#    '$1m',
#    'run',
#    'gif',
#    'primetime',
#    'ads',
#    'gets',
#    'vote'],
#   'Negative'),
#  (['make',
#    'easier',
#    'younger',
#    'folks',
#    'understand...',
#    'douchebaggery',
#    'game',
#    'fleek!'],
#   'Negative'),
#  (['usually', 'politics...but', 'good', 'entertainment'], 'Positive'),
#  (['reminder:', 'bush', 'run', 'florida'], 'Negative'),
#  (['lived', 'florida', 'years', 'jeb', 'bush', 'swear,', 'more...'],
#   'Negative'),
#  (['sure', 'was.', 'delivered', 'message', 'well.'], 'Positive'),
#  (['ben',
#    'carson:',
#    'one',
#    'seems',
#    'see',
#    'cares',
#    'say',
#    'racism',
#    'doesnt',
#    'exist.'],
#   'Positive'),
#  (['difference',
#    '&amp;',
#    'candidates',
#    'i’m',
#    'honest',
#    '&amp;',
#    'women',
#    'beautiful.'],
#   'Negative'),
#  (["i'd",
#    'like',
#    'see',
#    'bunch',
#    'losers',
#    'work',
#    'construction',
#    "they're",
#    'years',
#    'old.'],
#   'Negative'),
#  (["that's", 'all!'], 'Negative'),
#  (['.@johnkasich', 'debate', 'little', 'home', 'field', 'advantage.'],
#   'Positive'),
#  (['thinking', 'appropriate', 'bitterness', 'stage'], 'Positive'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['ask',
#    'trump',
#    'legitimate',
#    'question.',
#    'look',
#    "wallace's",
#    'face',
#    'trump',
#    'nails',
#    'it.'],
#   'Negative'),
#  (['dear',
#    'nobody',
#    'likes',
#    'abortion,',
#    'want',
#    'republicans',
#    'raping',
#    'children',
#    'getting',
#    'away',
#    'it.'],
#   'Negative'),
#  (['fundamental', 'problem', 'gop', 'party'], 'Negative'),
#  (['woman',
#    '&amp;',
#    'offended',
#    'needs',
#    'say',
#    'women',
#    'rather',
#    'sensitive',
#    'liberal',
#    'women!'],
#   'Negative'),
#  (['cries',
#    'preschooler',
#    'cant',
#    'stand',
#    'woman',
#    'brought',
#    'down.',
#    'hes',
#    'disgusting',
#    'pig.'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['candidate',
#    'received',
#    'word',
#    'god?!',
#    'presidential',
#    'hopefuls?!',
#    'america?!',
#    'christian',
#    'brotherhood',
#    'america'],
#   'Negative'),
#  (['ignored',
#    'america’s',
#    'million',
#    'poor,',
#    'didn’t',
#    'stop',
#    'candidates',
#    'mentioning',
#    '“immigration”',
#    '“illegal”',
#    'real',
#    'threat'],
#   'Negative'),
#  (['men', 'stage', 'discussing', 'one', 'woman.'], 'Negative'),
#  (['killing', 'joe', 'putting', 'john'], 'Negative'),
#  (['totally', 'fair', 'especially', '1st', '2mins'], 'Negative'),
#  (['thank',
#    'support',
#    'single',
#    'payer',
#    'last',
#    'night',
#    'hope',
#    'supporters',
#    'agree',
#    'also!'],
#   'Positive'),
#  (['big',
#    'problem',
#    'facing',
#    'democrats',
#    'get',
#    'hillary',
#    'sober',
#    'long',
#    'enough',
#    'debate?'],
#   'Negative'),
#  (["can't",
#    'fucking',
#    'leave',
#    'school',
#    'curriculum',
#    'decided',
#    'states,',
#    'south',
#    'abolish',
#    'biology',
#    'lmfao'],
#   'Negative'),
#  (["that's", 'exactly', 'feel', 'hardly', 'worth', 'discussing.', 'wow.'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Positive'),
#  (['"conservatives',
#    'want',
#    'live',
#    'babies',
#    'raise',
#    'dead',
#    'soldiers."',
#    '-george',
#    'carlin'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['fox',
#    'presidential',
#    'candidates:',
#    'lets',
#    'talk',
#    'god',
#    'second.',
#    'founding',
#    'fathers:',
#    'jesus:'],
#   'Negative'),
#  (['omg',
#    'hope',
#    'none',
#    'think',
#    "they've",
#    'heard',
#    'god.',
#    'could',
#    'without',
#    'schizo',
#    'office.'],
#   'Negative'),
#  (['nice',
#    'work',
#    'asking',
#    'tough',
#    "q's",
#    'speaking',
#    'young',
#    "rep's,",
#    'hearts!'],
#   'Positive'),
#  (['fact',
#    'young',
#    'adults',
#    'think',
#    'biggest',
#    'issue',
#    '2016',
#    'presidential',
#    'elections',
#    'scary...'],
#   'Negative'),
#  (['also',
#    'get',
#    'sense',
#    'actually',
#    'competent',
#    'executive',
#    'hillary',
#    'clinton',
#    'pretends',
#    'be,',
#    'neve…'],
#   'Positive'),
#  (['they...', 'say', 'god', 'would', 'break?'], 'Negative'),
#  (["i'm",
#    'thoroughly',
#    'disgusted',
#    'abysmal',
#    'performance',
#    'demonstrated',
#    'last',
#    'night',
#    'owe',
#    'candidate',
#    'apology.'],
#   'Negative'),
#  (['jeb',
#    'bush:',
#    'defunded',
#    'planned',
#    'parenthood"',
#    '....he',
#    'proud',
#    'denied',
#    'thousands',
#    'women',
#    'access',
#    'life',
#    'saving',
#    'healthcare...'],
#   'Negative'),
#  (['watching',
#    'seems',
#    'like',
#    'bashing',
#    'pbo',
#    '"failed',
#    'policies"',
#    'impo…'],
#   'Negative'),
#  (['president,', 'always', 'tell', 'truth,', 'said', 'would', 'do.'],
#   'Positive'),
#  (['interview', 're:', 'outstanding', 'debate', 'performance.'], 'Positive'),
#  (['*i*',
#    'hate',
#    'planned',
#    'parenthood',
#    'women',
#    'more!',
#    'hate',
#    'planned',
#    'parenthood',
#    'women',
#    'more!!!!!'],
#   'Negative'),
#  (['jeb',
#    'bush:',
#    'proven',
#    'conservative',
#    'record',
#    '&amp;',
#    'proven',
#    'record',
#    'winning'],
#   'Positive'),
#  (["i'm", 'ready', 'fire', 'politicians!'], 'Negative'),
#  (['donald', 'trump', 'late-night', 'angry-tweets', 'megyn', 'kelly,', 'epic'],
#   'Negative'),
#  (['fox',
#    'clearly',
#    'forgot',
#    'entire',
#    'issue',
#    'someone',
#    'audience',
#    'jump',
#    'in.',
#    'fox',
#    'big',
#    'loser',
#    'last',
#    'night.#gopdebate'],
#   'Negative'),
#  (['changed', 'mind', 'going', 'watch', 'weekend,', 'nothing', 'could', 'bad'],
#   'Negative'),
#  (['.@miamidecor',
#    'cancel',
#    'primaries.',
#    'fox',
#    'party',
#    'set',
#    '&amp;',
#    'anointed',
#    'man',
#    'jeb',
#    'bush'],
#   'Negative'),
#  (['fox',
#    'news',
#    'admit',
#    'republican',
#    'leader',
#    'right',
#    'mean',
#    'double-digit',
#    'lead'],
#   'Negative'),
#  (["i'm",
#    'pretty',
#    'sure',
#    'donald',
#    'trump',
#    'said',
#    'held',
#    'responsible',
#    'says',
#    'social',
#    'media'],
#   'Negative'),
#  (['saying',
#    '"all',
#    'lives',
#    'matter"',
#    'worth',
#    'points',
#    'league.',
#    'missed',
#    'opportunity',
#    'there.'],
#   'Negative'),
#  (['favorite', 'quote', 'night', '"freedom', 'free"'], 'Positive'),
#  (['fox',
#    'silenced',
#    'koch',
#    'billions',
#    'too?',
#    'single',
#    'question',
#    'last',
#    "night's",
#    'deniers',
#    'mond…'],
#   'Negative'),
#  (['media',
#    'sticks',
#    'rips',
#    "media'is",
#    'missing',
#    'crash',
#    'burn.',
#    'megan',
#    'set',
#    'trump',
#    'up.'],
#   'Negative'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Positive'),
#  (['make', 'happen,', "cap'n!!", 'responses', 'spot', 'on.', 'thank', 'you!!'],
#   'Positive'),
#  (['think', 'vicious', 'unprofessional', 'last', 'night.', 'lost', 'also.'],
#   'Negative'),
#  (['damn', 'christian', 'revival.', 'cut', 'out.'], 'Negative'),
#  (['others',
#    'treated',
#    'like',
#    'treat',
#    'cranky',
#    'toddler:',
#    'nice,',
#    'stay',
#    'calm,',
#    'know',
#    'find',
#    'new',
#    'toy',
#    'play',
#    'soon.'],
#   'Negative'),
#  (['absolutely',
#    'questions',
#    'jobs',
#    'economy?',
#    "that's",
#    'polling',
#    'highest,',
#    'right?'],
#   'Negative'),
#  (['trump', 'cam', 'hands.'], 'Positive'),
#  (['"i\'m', 'guy', 'stage', 'who..."', "christie's", 'theme', 'bad', 'theme.'],
#   'Positive'),
#  (['ignorant.',
#    'presidential.',
#    'class',
#    'money.',
#    'clearly',
#    'money',
#    "can't",
#    'buy',
#    'class',
#    '&amp;',
#    'skipped',
#    'dignity',
#    'too.'],
#   'Negative'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Negative'),
#  (['much',
#    'fun',
#    'isurfed',
#    'around',
#    'bot',
#    'always',
#    'ended',
#    'back',
#    'there.',
#    'non',
#    'thinkers',
#    'one',
#    'place'],
#   'Negative'),
#  (['marco', 'rubio', 'debating', 'like', 'champ.'], 'Positive'),
#  (['minutes', 'voters', 'spoken.'], 'Negative'),
#  (['enjoyed', 'looking', 'forward', 'next.'], 'Positive'),
#  (['trainwreck',
#    'truest',
#    'sense',
#    'word.',
#    'painfully',
#    'awkward',
#    'opening',
#    'nonsensical',
#    'answers',
#    'questions'],
#   'Negative'),
#  (['tame',
#    'reporting',
#    'bbc.',
#    'must',
#    'best',
#    '"show"',
#    'last',
#    'night!',
#    'wish',
#    "i'd",
#    'seen',
#    'it!'],
#   'Negative'),
#  (['hashtag',
#    'use',
#    'vote',
#    'candidates',
#    'receive',
#    'injuries',
#    'illnesses',
#    'descend',
#    'poverty?'],
#   'Negative'),
#  (['well,',
#    'perfected',
#    'photoshop',
#    'totally',
#    'made',
#    'fall',
#    'pic',
#    'stefon',
#    'regarding'],
#   'Negative'),
#  (['candidates', 'attack', 'fox', 'stoping', 'speaking.'], 'Negative'),
#  (['huge',
#    'local',
#    'ratings',
#    'nashville',
#    'last',
#    'night:',
#    '14.3.',
#    'show',
#    'nashville',
#    'yesterday',
#    'got',
#    'rating.'],
#   'Positive'),
#  (['boy',
#    "i'm",
#    'fan',
#    'damn',
#    "can't",
#    'let',
#    'bozos',
#    'become',
#    "can't",
#    'worse',
#    'guys'],
#   'Negative'),
#  (['okay', "i'm", 'listening', 'now.', 'amazing', 'last', 'night!'],
#   'Positive'),
#  (['wait!', 'wuuuuuuuut?', 'actually', 'question?', "can't"], 'Negative'),
#  (['know', "he's", 'sorta', 'busy,', 'post-debate', 'discussion', 'without'],
#   'Negative'),
# ...
#  (['become', 'acceptable', 'god', 'topic', 'political', 'debates', 'country?'],
#   'Negative'),
#  (['chris',
#    'christie:',
#    '"bill',
#    'rights?"',
#    '"constitution?"',
#    '"never',
#    'heard',
#    '\'em."'],
#   'Negative'),
#  (['politicians',
#    'call',
#    '“immigration',
#    'reform”',
#    'don’t',
#    'want',
#    'call',
#    'making',
#    'illegal',
#    'immigration,',
#    'legal!'],
#   'Negative'),
#  (['huck', 'say', 'wants', 'protect', 'benefits', 'pimps', 'prostitutes?'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['many',
#    'executive',
#    'orders',
#    'passed,n',
#    'many',
#    'bombs',
#    'dropped',
#    'syria',
#    'populace',
#    'glued',
#    '2them',
#    "talkin'",
#    'picture',
#    'boxe…'],
#   'Negative'),
#  (['hey',
#    'jeb',
#    'bush,',
#    'nothing',
#    'replace',
#    'obamacare',
#    'give',
#    'break,',
#    'fu***ng',
#    'asshole.'],
#   'Negative'),
#  (['amazing',
#    'tweeting',
#    'w/all',
#    'tonight',
#    'grateful',
#    '&amp;',
#    'look',
#    'forward',
#    'fun',
#    'ahead!'],
#   'Positive'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['chase',
#    'norton',
#    'wants',
#    'know',
#    'received',
#    'word',
#    'god',
#    'vote',
#    'challenge!!'],
#   'Negative'),
#  (['lost',
#    'insanity',
#    'foxnews',
#    'completely',
#    'shilling',
#    'gop,',
#    'pretending',
#    'impartial.'],
#   'Negative'),
#  (['loved',
#    'exasperated',
#    'look',
#    "jeb's",
#    'face',
#    'like',
#    'kept',
#    'thinking,',
#    '"am',
#    'one',
#    'taking',
#    'seriously?"'],
#   'Negative'),
#  (['apparently',
#    'trump,',
#    '"tell',
#    'like',
#    'is"',
#    'guy,',
#    "can't",
#    'handle',
#    'tough',
#    'questions',
#    'point',
#    'utter',
#    'hypocrisy.'],
#   'Negative'),
#  (['candidates', 'attack', 'fox', 'stoping', 'speaking.'], 'Positive'),
#  (['america', 'gives', 'fox', 'low', 'marks', 'last', 'night.'], 'Negative'),
#  (["i'd",
#    'really',
#    'like',
#    'see',
#    'long',
#    'candidate',
#    'given',
#    'speak.',
#    'seem',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'all.'],
#   'Negative'),
#  (['donald',
#    'trump',
#    'think',
#    'last',
#    'night',
#    'never',
#    'actually',
#    'answered',
#    'questions?'],
#   'Negative'),
#  (['seriously,', 'would', 'vote', 'clowns?', 'need'], 'Negative'),
#  (['know',
#    'rwers',
#    'like',
#    'show',
#    'power,but',
#    'rub',
#    '5:00',
#    'candidates',
#    'noses',
#    'fact'],
#   'Negative'),
#  (['put',
#    'men',
#    'stage',
#    'one',
#    'body',
#    'still',
#    'one',
#    'decent',
#    'president.'],
#   'Negative'),
#  (['really',
#    'think',
#    'alliance',
#    'order!',
#    'would',
#    'political',
#    'powerhouse!'],
#   'Positive'),
#  (['bad',
#    'job,',
#    'reporter',
#    'never',
#    'scold',
#    '&amp;',
#    'say',
#    'things',
#    'like,',
#    '"you',
#    'mean',
#    'tell',
#    'me???"',
#    'better.'],
#   'Negative'),
#  (['trump:', '"more', 'adam', 'sandler', 'movies!"'], 'Negative'),
#  (['weave',
#    'head',
#    'look',
#    'like',
#    'hair.',
#    'see',
#    'anymore',
#    'glue,',
#    'scream.',
#    'looking',
#    'like',
#    'trump'],
#   'Negative'),
#  (["trump's",
#    'entire',
#    'performance:',
#    'hate',
#    'player.',
#    'rules',
#    'made',
#    'me,',
#    'love',
#    'it.'],
#   'Positive'),
#  (['hot',
#    'mess',
#    '&amp;',
#    'gets',
#    'blame',
#    'setup',
#    'crush',
#    'ignore',
#    '&amp;',
#    'prop'],
#   'Negative'),
#  (['"mr.trump,',
#    'called',
#    'women',
#    'fat',
#    'pigs,',
#    'dogs,',
#    'slobs,',
#    'disgusting',
#    'animals..."',
#    '"only',
#    'rosie',
#    'o\'donnell."',
#    '*laughter,',
#    'applause*'],
#   'Negative'),
#  (['back', 'canada', 'asshole'], 'Negative'),
#  (['funny',
#    'see',
#    'megyn',
#    'pretend',
#    'stick',
#    'women',
#    '(vs',
#    'trump)',
#    'championing',
#    'party',
#    'hates',
#    'woman',
#    'every',
#    'single',
#    'day.'],
#   'Negative'),
#  (['like', 'watching', 'bunch', 'chimps', 'throw', 'shit', 'other.'],
#   'Negative'),
#  (['half', 'long', 'twice', 'intelligible.'], 'Negative'),
#  (['moment', 'realize', 'watching', 'fox', 'news', 'handcuffs.'], 'Negative'),
#  (['need',
#    'check',
#    'source,',
#    'seems',
#    'like',
#    'something',
#    'logical',
#    'would',
#    'say'],
#   'Negative'),
#  (['trump', 'companies', 'went', 'bankrupt,', 'wants', 'fix', 'u.s.', 'debt?'],
#   'Negative'),
#  (['build', 'fence', 'around', 'trump?'], 'Negative'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['government',
#    'secured',
#    'bonds',
#    'ious.',
#    'are,',
#    'one',
#    'better',
#    'tell',
#    'china.'],
#   'Negative'),
#  (['defund',
#    'planned',
#    'parenthood!"',
#    'fuck',
#    'reproductive',
#    'health',
#    'amirite???',
#    'less',
#    'sex',
#    'ed!',
#    'babies!'],
#   'Negative'),
#  (['need',
#    'order',
#    'another',
#    'green',
#    'apple',
#    'martini',
#    'process',
#    'hell',
#    'happened.'],
#   'Negative'),
#  (['cats', 'act', 'like', 'hate', 'women,', 'blacks', 'mexicans'], 'Negative'),
#  (['would', 'never', 'know', 'frontrunner', 'watching', 'debate.'],
#   'Positive'),
#  (['rand',
#    'paul',
#    "christie's",
#    'jealous',
#    'boyfriend.',
#    "'you",
#    'hug',
#    "want'",
#    'lol'],
#   'Negative'),
#  (['supporters', 'saying', 'treated', '"unfairly?"', 'yea...', 'right.'],
#   'Negative'),
#  (['kijivu,',
#    'gorilla',
#    'prague',
#    'zoo,',
#    'reacts',
#    'primate',
#    'aggression',
#    'displays',
#    'u.s.'],
#   'Negative'),
#  (['wait', 'said', 'use', 'says', '"when', 'used', 'it?"'], 'Negative'),
#  (['leaders',
#    'make',
#    'tax-payers',
#    'fund',
#    'even',
#    'beliefs,',
#    'trump',
#    "can't",
#    'call',
#    'person',
#    'disgusting',
#    'animal.'],
#   'Negative'),
#  (['featured', 'candidates', 'brain', 'cells.'], 'Negative'),
#  (['pointed',
#    'out,',
#    'huge',
#    'audience',
#    'poc',
#    'ready',
#    'learn.',
#    'learned',
#    'mostly',
#    'scary.'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['miss',
#    'days',
#    'conservatives',
#    'wanted',
#    'presidential',
#    'candidate',
#    'was,',
#    'know,',
#    'conservative...'],
#   'Negative'),
#  (['arrogant',
#    'press-aholes',
#    'thinks',
#    'right',
#    '2pick',
#    'next',
#    'president?',
#    'not!',
#    'ours!'],
#   'Negative'),
#  (['seriously:',
#    'gop',
#    'voters',
#    'think',
#    'god',
#    'talks',
#    'presidential',
#    'candidates?'],
#   'Negative'),
#  (['-can', 'answer', 'direct', 'question?', 'president.', '-so,', 'no?'],
#   'Negative'),
#  (['second', 'most-retweeted', 'presidential', 'candidate', 'tweet'],
#   'Positive'),
#  (['best', 'video', 'ever', '!!!!!!', 'night', 'roxbury', 'lol'], 'Positive'),
#  (['haven’t',
#    'heard',
#    'him,',
#    'personally',
#    'addressed',
#    'god',
#    'many',
#    'times',
#    'tonight',
#    'watching'],
#   'Negative'),
#  (['would',
#    'see',
#    'radical',
#    'liked',
#    'idea',
#    'using',
#    '5th',
#    '14th',
#    'amendments',
#    'stop',
#    'abortion'],
#   'Positive'),
#  (['meet',
#    'scott',
#    'walker’s',
#    'paranoid,',
#    'insurrectionist',
#    'adviser',
#    'police',
#    'violence',
#    'african...'],
#   'Negative'),
#  (['☞retweet☜', 'agree', 'candidates', 'better', 'clinton.'], 'Positive'),
#  (['gop',
#    'candidates',
#    'discussing',
#    'illegal',
#    'immigration',
#    'pure',
#    'theater.',
#    'except',
#    'theater',
#    'creates',
#    'jobs.'],
#   'Negative'),
#  (['well', 'carson...did', 'dance', 'away', 'race', 'issues', 'country???'],
#   'Negative'),
#  (["i'd", 'love', 'body', 'shot', 'marco', "rubio's", 'ears.'], 'Negative'),
#  (['dr.',
#    'seriously',
#    'saying',
#    'hillary',
#    'clinton',
#    'trying',
#    'destroy',
#    'america',
#    "that's",
#    'ridiculous',
#    '&amp;',
#    'shame',
#    'lies'],
#   'Negative'),
#  (["can't", 'wait', 'remember', 'bros', 'names.'], 'Negative'),
#  (['mess!!!'], 'Negative'),
#  (['pathetic',
#    '&amp;',
#    'transparent',
#    '-&gt;.@frankluntz',
#    'goes',
#    'right',
#    '&amp;',
#    'best',
#    'push',
#    'rhinos!'],
#   'Negative'),
#  (['overnight',
#    '16.0',
#    'household',
#    'rating.',
#    'biggest',
#    'gop',
#    'debates',
#    '2011/12',
#    '5.3',
#    'ratings'],
#   'Positive'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['huckabee',
#    'says',
#    'fetus',
#    'constitutional',
#    'rights',
#    'yet',
#    'social',
#    'security',
#    'number,',
#    'much',
#    'like',
#    'illegals.'],
#   'Negative'),
#  (['murder', 'black', 'ppl', 'fine-', 'unborn', 'black', 'babies?'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['learn?', 'attack', 'wins', '&amp;', 'poll.'], 'Negative'),
#  (['&amp;', 'chris', 'wallace', 'acted', 'like', '"reporters."'], 'Negative'),
#  (['know', 'bad', 'trump', 'comes', 'looking', 'like', 'champ', 'situation'],
#   'Negative'),
#  (['donald',
#    'trump',
#    'says',
#    'everyone',
#    'stupid',
#    'ben',
#    'carson',
#    'says',
#    'everyone',
#    'uninformed,',
#    'useful',
#    'idiot...we',
#    'worthy'],
#   'Negative'),
#  (['watched',
#    'last',
#    'night',
#    'damn,',
#    'trump',
#    'went',
#    'off.polls',
#    'showing',
#    'people',
#    'think',
#    'interesting',
#    'goin',
#    'fwd'],
#   'Negative'),
#  (['.@borowitzreport', 'assesses', "walker's", 'performance,', 'via'],
#   'Positive'),
#  (['2nd', 'favorite', 'meme', 'internet!'], 'Negative'),
#  (['kid', 'feels'], 'Negative'),
#  (['brother',
#    'guy',
#    'almost',
#    'plunged',
#    'u.s.',
#    'great',
#    'depression',
#    'telling',
#    'guy',
#    'fixed',
#    'problem',
#    'amer…'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Positive'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['scott',
#    'walker',
#    'cut',
#    'answers',
#    'short',
#    'last',
#    'night,',
#    'finishing',
#    'allotted',
#    'time.',
#    'marquette',
#    '"we\'ve',
#    'seen',
#    'before."'],
#   'Negative'),
#  (['took',
#    'days',
#    'lower',
#    'flag',
#    'honor',
#    'soldiers',
#    'killed',
#    'trump',
#    'better',
#    'call',
#    'woman',
#    'slob.'],
#   'Negative'),
#  (['learn', 'get', 'away', 'sexism', 'easy', 'steps', 'via'], 'Negative'),
#  (['missed', 'first', 'minutes', 'last', "night's", 'got', 'see', 'this:'],
#   'Positive'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['guy...'], 'Negative'),
#  (['says',
#    'respects',
#    'take',
#    'care',
#    'poor',
#    '&amp;',
#    'sick',
#    '...bad',
#    'news',
#    "he's",
#    'getting',
#    'nomination'],
#   'Positive'),
#  (['"the',
#    'purpose',
#    'military',
#    'kill',
#    'people',
#    'break',
#    'things"',
#    'first',
#    'time',
#    "i've",
#    'ever',
#    'agreed',
#    'mike',
#    'huckabee'],
#   'Negative'),
#  (['talked', 'pre-debate', 'ritual.', 'take', 'solitaire', 'seriously.'],
#   'Positive'),
#  (["we're",
#    'sick',
#    'political',
#    'correctness,',
#    'killing',
#    'heart',
#    'soul',
#    'country.'],
#   'Positive'),
#  (['wish',
#    'hilary',
#    'carly',
#    'fiorina',
#    'passion',
#    'spark!',
#    'take',
#    'lessons',
#    'her.#gopdebate'],
#   'Positive'),
#  (['beautiful', 'night', 'watching', 'playing…'], 'Positive'),
#  (['looked',
#    'like',
#    'fun.',
#    'though',
#    'think',
#    'missed',
#    'swimsuit',
#    'talent',
#    'contest',
#    'rounds.'],
#   'Negative'),
#  (['trump',
#    'like',
#    'obama',
#    'refuse',
#    'communicate',
#    'saying',
#    'anything',
#    'like.'],
#   'Negative'),
#  (['carson,',
#    'carson,',
#    'carson:',
#    'dammit',
#    'man!',
#    'say',
#    'words',
#    'racism',
#    'white',
#    'supremacy',
#    'audience!'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['hillary', 'clinton', 'spent', 'night', 'kardashians:'], 'Negative'),
#  (['pose',
#    'awkward.',
#    'hell',
#    'work',
#    'with?',
#    'stiff,',
#    'natural.',
#    'kinda',
#    'like',
#    'last',
#    'night.'],
#   'Negative'),
#  (['[helen',
#    'lovejoy',
#    'voice]',
#    'somebody',
#    'please',
#    'think',
#    'christians?'],
#   'Negative'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['"we\'ve', 'seen', 'proposal', 'plan'], 'Negative'),
#  (['people',
#    'last',
#    'night',
#    'denying',
#    'support',
#    'rape/incest',
#    'exception',
#    'like',
#    'bad',
#    'thing...'],
#   'Negative'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Positive'),
#  (['aaaand',
#    'brings',
#    'dnc',
#    'chair',
#    'take',
#    'trump',
#    'thru',
#    "women's",
#    'rights.',
#    'gender',
#    'used',
#    'fear',
#    'tool.',
#    'ugh'],
#   'Negative'),
#  (['treated', 'like', 'little', 'gnat', 'is.'], 'Positive'),
#  (['"when',
#    'find',
#    'mush,',
#    'push"',
#    'agree',
#    'jack',
#    'great',
#    'motto',
#    'life!',
#    '(from',
#    'last',
#    "night's"],
#   'Negative'),
#  (['put',
#    'men',
#    'stage',
#    'one',
#    'body',
#    'still',
#    'one',
#    'decent',
#    'president.'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['really',
#    'liked',
#    'many',
#    'candidates',
#    'people',
#    'much',
#    'future',
#    'presidents.'],
#   'Negative'),
#  (['huckabee.'], 'Negative'),
#  (['koch',
#    'puppet',
#    'speaking',
#    'exactly',
#    "he's",
#    'told',
#    'say.',
#    '"well',
#    'done',
#    'david!',
#    '"well',
#    'done',
#    'charles!"'],
#   'Negative'),
#  (['clue',
#    'kind',
#    'hard',
#    'work',
#    '&amp;',
#    'commitment',
#    'every',
#    'member',
#    'military',
#    'makes.'],
#   'Negative'),
#  (['believable', 'funny', 'guy', 'great'], 'Positive'),
#  (['"trust', 'vilify"', 'line', 'years', 'ago', 'gop', 'neocons.'],
#   'Negative'),
#  (['wow', 'governor', 'huckabee', 'fantastic!'], 'Positive'),
#  (['notice', 'nodding', 'agreement', 'talked', 'operating', 'brain?'],
#   'Negative'),
#  (['.@drudge_report',
#    'trump',
#    'took',
#    'megyn',
#    'kelly',
#    'church',
#    'last',
#    'night.',
#    'dominant',
#    'showing.'],
#   'Negative'),
#  (['resemblance?'], 'Negative'),
#  (['"i\'m',
#    'new',
#    'kind',
#    'republican',
#    'moving',
#    'party',
#    'forward!',
#    'women',
#    'control',
#    'bodies!"',
#    'republicans'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['moment', 'realize', 'watching', 'fox', 'news', 'handcuffs.'], 'Negative'),
#  (['retweeted',
#    'comment',
#    'calling',
#    '"bimbo"',
#    'last',
#    'night.',
#    'man',
#    'hates',
#    'women.',
#    'front',
#    'runner.'],
#   'Negative'),
#  (['donald', 'trump,', 'democratic', 'spy?'], 'Negative'),
#  (['hugely', 'entertaining.', 'sadly,', 'learned', 'almost', 'nothing'],
#   'Negative'),
#  (['debates', 'raise', 'ratings', 'fox', 'news', 'afraid', 'trump', 'shows.'],
#   'Positive'),
#  (['trump',
#    'said,',
#    '"megyn,',
#    'ask',
#    'nine',
#    'candidates,',
#    'plan',
#    'support',
#    'win',
#    'nomination."'],
#   'Negative'),
#  (['many', 'great', 'jokes', 'twitter', 'tonight', 'many', 'stage.'],
#   'Negative'),
#  (['fact:', 'jeb', 'governor,', 'florida', 'run', 'death', 'cult.'],
#   'Negative'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['wants', 'hug?'], 'Positive'),
#  (['good',
#    'you,',
#    'megyn',
#    'kelly,',
#    'calling',
#    'ben',
#    'carson',
#    'idiot',
#    'right',
#    'bat.'],
#   'Negative'),
#  (['.@foxnews',
#    'focus',
#    'group:',
#    '"he',
#    'articulate,',
#    'relatable,',
#    '&amp;',
#    'made',
#    'lot',
#    'good',
#    'points."'],
#   'Positive'),
#  (['media',
#    'seem',
#    'leaving',
#    'disturbing',
#    'comments',
#    'trump',
#    'made',
#    'megan',
#    'kelly',
#    'made',
#    'veiled',
#    'threat',
#    'her.'],
#   'Negative'),
#  (['headed', 'presidential', 'debates.', 'ted!!'], 'Positive'),
#  (['cands/mods:',
#    'trump,',
#    "can't",
#    'run',
#    'independent!',
#    "we'll",
#    'lose!',
#    'me:',
#    'last',
#    'pick',
#    'said',
#    'real',
#    'live',
#    'person.'],
#   'Negative'),
#  ...]

# %%
# extracting word features 
def get_words_in_tweets(tweets):
    all_=[]
    for (words,sentiment) in tweets:
        all_.extend(words)
    return all_

def get_word_features(wordlist):
    wordlist=nltk.FreqDist(wordlist)
    features=wordlist.keys()
    
    return features 

w_features=get_word_features(get_words_in_tweets(tweets))

def extract_features(document):
    document_words=set(document)
    features={}
    for word in w_features:
        features['contain({})'.format(word)]= (word in document_words)
        
    return features

# %%
print(w_features)
# Out:
# dict_keys(['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.', "i'd", 'really', 'like', 'see', 'long', 'candidate', 'given', 'speak.', 'seem', '"fair', '&amp;', 'balanced"', 'all.', '"but', 'wanna', 'eat', 'vegetables"', "let's", 'change', 'racist', 'usage', 'word', 'articulate', 'describe', 'republicans', 'well', 'spoken.', 'built', 'massive', 'database', 'gun', 'owners', 'opposing', 'national', 'registry', 'candidates', 'attack', 'fox', 'stoping', 'speaking.', 'koch', 'ted', "cruz's", 'mutant', 'superpower', 'fear-mongering.', 'huckabee:', '"we', 'need', 'banish', 'department', 'education!', "can't", 'voters', 'educated!!"', 'ask', 'trump', 'legitimate', 'question.', 'look', "wallace's", 'face', 'nails', 'it.', 'thin-skinned', 'feel', 'sorry', 'fool', 'us.', "i'll", 'tell', 'one', 'good', 'thing', 'tripping', 'outdo', 'sexism…', 'best', 'wiping', 'floor', 'jihad', 'enabling', 'policies.', 'done.', 'american', 'people', 'pick', 'next', 'president', 'united', 'states', 'news', 'nope.', 'think', 'unintentionally', 'funny', 'political', 'event', "i've", 'ever', 'seen.', 'great!', 'thanks', 'news,', 'raising', 'ratings.', 'actually', 'trump,', 'live', 'least', 'violent', 'time', 'human', 'history.', 'person', 'worse', 'kasich', 'last', 'night', 'megyn', 'kelly…', 'kelly:', 'would', 'defeat', 'isis', 'days?', 'cruz:', 'green', 'lantern', 'ring,', 'course.', 'spoiler', 'alert:', 'every', 'thinks', 'knows', 'wants.', 'anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?', 'politicans', 'finances', 'money', 'comes', 'from?', 'clown', 'show.', 'abortion', 'murder', "y'all,", 'cops', 'keep', 'abusing', 'system', 'murdering', 'black', "y'all", 'quiet?', 'focus', 'group', 'laugh.', 'statistically', 'significant.', 'audience', 'loves', 'carson', "what's", 'thoughts', 'comments', 'facebook', 'page', 'concerning', 'motive', 'behind', '"stay', 'tuned', 'closing', 'statements,', 'final', 'thoughts,', 'god."', 'turned', 'tv,', "i'm", 'good.', 'enjoyed', 'looking', 'forward', 'next.', 'smart', 'say,', 'essentially,', 'concerns', 'except', 'sane"', 'commentators', 'saying', 'watch', "he's", 'making', 'som…', 'waters,', 'rising', 'fast;', 'history', 'catching', 'last.', "that's", 'nutshell.', 'aldon', 'smith', 'king', 'very,', 'put', 'politely,', 'macho?', 'argue', 'penis', 'size', 'generally', 'small', 'ones.', 'walker:', 'god', 'cutting', 'budget.', 'talk', 'him.', '.@allahpundit', 'part', "rush's", 'opening--his', 'reporting', 'backlash', "they've", 'forgotten', 'hugged', 'obama', 'deserve', 'stage', 'tonight.', 'cam', 'hands.', 'no,', 'scott', 'walker,', '"lash"', 'protesters', 'wisconsin...', 'arrested.', 'likes', 'socialized', 'med', 'paying', 'corrupt', 'politicians.', 'conservatives', 'him,', 'why?#gopdebate', '.@thepoliticalcat', 'cancel', 'primaries.', 'party', 'set', 'anointed', 'man', "trump's", 'questions', 'tougher', "else's.", 'get', 'center', 'gotta', 'able', 'take', 'heat.', 'color', 'audience?', 'i’m', 'asking', 'friend.', 'love', 'talking', 'kinds', 'shit', 'men', 'discussing', 'woman.', 'conservative', 'christie', 'night,', 'leave', 'immediately.', 'country', 'make', 'top', 'watching', 'television,', 'staff', 'livetweeting', 'yells', 'tv:', 'america', 'horrified', 'santorum', 'taps', 'rage!', 'tried', 'marginalize', 'w/"social', 'ques"', 'saw', 'before...last', 'night...likely', 'lost', '"#chubclub"', 'vote..', 'rosie', "o'donnell.", 'ignore', 'pundit', 'blither.', 'biggest', 'winner', "night's", 'full', 'stop.', 'disappointing', 'conducting', 'debate.', 'watched', 'honestly', 'say', 'vote', 'rock', 'democrat.', 'so…', '"this', 'worst', 'miss', 'competition', 'seen."', '-@thejoemoses', 'great', 'one!!!!!', 'gop', 'secret', 'crush', 'hillary', 'trashing', 'much.', 'intention', 'voting', 'guy', 'brand', 'wil', 'give', 'credit', 'stirring', 'things', 'hate', '.@realdonaldtrump?', 'never', 'forget...', 'created', 'this.', 'spoke', 'now?', 'cuz', 'heard', 'busy', 'sure', 'women', 'could', 'still', 'healthcare ...

# %%
wordcloud_draw(w_features)
